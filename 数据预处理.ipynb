# %%
import json 
import numpy as np 
with open('./data/info_list.json', 'r') as f:
    text = json.load(f)
text
# Out:
# {'Abelia chinensis': {'canonical_name': 'Abelia chinensis',
#   'c_name': '糯米条',
#   'common_name': None,
#   'family': {'kingdom': 'Plantae',
#    'phylum': 'Angiospermae',
#    'class': 'Magnoliopsida',
#    'order': 'Dipsacales',
#    'family': 'Caprifoliaceae',
#    'genus': 'Abelia'},
#   'c_family': {'界': '植物界',
#    '门': '被子植物门',
#    '纲': '木兰纲',
#    '目': '川续断目',
#    '科': '忍冬科',
#    '属': '糯米条属'},
#   'distribution': ['江西',
#    '浙江',
#    '湖南',
#    '湖北',
#    '四川',
#    '云南',
#    '贵州',
#    '福建',
#    '台湾',
#    '广东',
#    '广西'],
#   'description': '落叶多分枝灌木，高达2米；嫩枝纤细，红褐色，被短柔毛，老枝树皮纵裂。叶有时三枚轮生，圆卵形至椭圆状卵形，顶端急尖或长渐尖，基部圆或心形，长2-5厘米，宽1-3.5厘米，边缘有稀疏圆锯齿，上面初时疏被短柔毛，下面基部主脉及侧脉密被白色长柔毛，花枝上部叶向上逐渐变小。聚伞花序生于小枝上部叶腋，由多数花序集合成一圆锥状花簇，总花梗被短柔毛，果期光滑；花芳香，具3对小苞片；小苞片矩圆形或披针形，具睫毛；萼筒圆柱形，被短柔毛，稍扁，具纵条纹，萼檐5裂，裂片椭圆形或倒卵状矩圆形，长5-6毫米，果期变红色；花冠白色至红色，漏斗状，长1-1.2厘米，为萼齿的一倍，外面被短柔毛，裂片5，圆卵形；雄蕊着生于花冠筒基部，花丝细长，伸出花冠筒外；花柱细长，柱头圆盘形。果实具宿存而略增大的萼裂片。'},
#  'Abelia × grandiflora': {'canonical_name': 'Abelia × grandiflora',
# ...

# %%
type(text)
# Out:
# dict

# %%
provinces_list = ['中国',"河北", "山西", "辽宁", "吉林", "黑龙江", "江苏", "浙江", "安徽", "福建", "江西","山东","河南","湖北","湖南","广东","海南","四川","贵州","云南","陕西","甘肃","青海","台湾", "内蒙古","广西",'西藏',"宁夏","新疆","北京",'天津',"上海","重庆","香港","澳门", '长江以南', '南方']

# %%
'he' in 'henana'
# Out:
# True

# %%
for index, item in enumerate(text):
    content = text[item]
    if 'distribution' in content:
        try:
            for  location in content['distribution']:
                if not location:
                    print(f'index {index} has no distribution!')
                elif location not in provinces_list:
                    print(f'index is {index}, location is {location}')
                    # for province in provinces_list:
                    #     if province in 
                    if '栽培于' in location:
                        location.replace('栽培于', '')
                        text[item]['distribution']
        except Exception:
            print(f'index {index}, name: {item}')
# Out:
# index is 9, location is 南方
# index 22, name: Acorus calamus
# index 23, name: Acorus gramineus
# index is 265, location is 华南
# index 281, name: Bulbophyllum ambrosia
# index is 285, location is 长江以南
# index is 332, location is 海南等
# index is 348, location is 不详
# index is 408, location is 在云南
# index is 427, location is 秦岭南坡以南各地栽种
# index is 428, location is 长江以南
# index is 429, location is 南方
# index is 444, location is 引种于安徽
# index is 522, location is 中国普遍
# index is 523, location is 南北普遍
# index is 529, location is 广西有
# index is 552, location is 西沙群岛
# index is 560, location is 南部
# index is 633, location is 云南有
# index is 634, location is 广西等省区
# index is 675, location is 南方
# index is 684, location is 于河北
# index is 691, location is 海南的热带地区
# index is 730, location is 野生地区
# index is 754, location is 中部
# index is 754, location is 北方
# index is 803, location is 西沙群岛
# index 810, name: Fissistigma thorelii
# index is 871, location is 澳门有
# index is 882, location is 长江流域
# ...
